# %% [markdown]
# # Project 1 -- Dat Le

# %% [markdown]
# **TA Help:**
#
#
#
# **Collaboration:** Anuj Shah
#
# + Help debug the code

# %% [markdown]
# ## Question 1

# %%
import pandas as pd
data = pd.read_csv("/anvil/projects/tdm/data/flights/subset/airports.csv")
data.head()
# Out:
#                lat         long
# count  3376.000000  3376.000000
# mean     40.036524   -98.621205
# std       8.329559    22.869458
# min       7.367222  -176.646031
# 25%      34.688427  -108.761121
# 50%      39.434449   -93.599425
# 75%      43.372612   -84.137519
# max      71.285448   145.621384

# %% [markdown]
# `pd.read_csv` to read csv and convert it into pandas dataframe
#
# `.head()` provides you $5$ first rows of the dataframe and the name of some of the first and last columns.

# %% [markdown]
# ## Question 2

# %%
%%R
dataR <- read.csv("/anvil/projects/tdm/data/flights/subset/airports.csv")
head(dataR)
# Out:
#   iata              airport             city state country      lat       long
# 1  00M             Thigpen       Bay Springs    MS     USA 31.95376  -89.23450
# 2  00R Livingston Municipal       Livingston    TX     USA 30.68586  -95.01793
# 3  00V          Meadow Lake Colorado Springs    CO     USA 38.94575 -104.56989
# 4  01G         Perry-Warsaw            Perry    NY     USA 42.74135  -78.05208
# 5  01J     Hilliard Airpark         Hilliard    FL     USA 30.68801  -81.90594
# 6  01M    Tishomingo County          Belmont    MS     USA 34.49167  -88.20111

# %%
dataR <- read.csv("/anvil/projects/tdm/data/flights/subset/airports.csv")
head(dataR)
# Out:
#   iata airport              city             state country lat      long
# 1 00M  Thigpen              Bay Springs      MS    USA     31.95376  -89.23450
# 2 00R  Livingston Municipal Livingston       TX    USA     30.68586  -95.01793
# 3 00V  Meadow Lake          Colorado Springs CO    USA     38.94575 -104.56989
# 4 01G  Perry-Warsaw         Perry            NY    USA     42.74135  -78.05208
# 5 01J  Hilliard Airpark     Hilliard         FL    USA     30.68801  -81.90594
# 6 01M  Tishomingo County    Belmont          MS    USA     34.49167  -88.20111

# %% [markdown]
# `%%R` lets us use different language without changing the kernel
#
# In R, we use `head()` instead, and `<-` is like equal
#
# Unlike Python, R shows $6$ rows with `head()` and the index starts from $1$

# %% [markdown]
# ## Question 3

# %%
#%%R
table(dataR$state)
# Out:
#  AK  AL  AR  AS  AZ  CA  CO  CQ  CT  DC  DE  FL  GA  GU  HI  IA  ID  IL  IN  KS
# 263  73  74   3  59 205  49   4  15   1   5 100  97   1  16  78  37  88  65  78
#  KY  LA  MA  MD  ME  MI  MN  MO  MS  MT  NC  ND  NE  NH  NJ  NM  NV  NY  OH  OK
#  50  55  30  18  34  94  89  74  72  71  72  52  73  14  35  51  32  97 100 102
#  OR  PA  PR  RI  SC  SD  TN  TX  UT  VA  VI  VT  WA  WI  WV  WY
#  57  71  11   6  52  57  70 209  35  47   5  13  65  84  24  32

# %%
head(dataR$state)
# Out:
# [1] "MS" "TX" "CO" "NY" "FL" "MS"

# %%
tail(dataR$state)
# Out:
# [1] "AZ" "NC" "PA" "FL" "NM" "OH"

# %%
sort(table(dataR$state))
# Out:
#  DC  GU  AS  CQ  DE  VI  RI  PR  VT  NH  CT  HI  MD  WV  MA  NV  WY  ME  NJ  UT
#   1   1   3   4   5   5   6  11  13  14  15  16  18  24  30  32  32  34  35  35
#  ID  VA  CO  KY  NM  ND  SC  LA  OR  SD  AZ  IN  WA  TN  MT  PA  MS  NC  AL  NE
#  37  47  49  50  51  52  52  55  57  57  59  65  65  70  71  71  72  72  73  73
#  AR  MO  IA  KS  WI  IL  MN  MI  GA  NY  FL  OH  OK  CA  TX  AK
#  74  74  78  78  84  88  89  94  97  97 100 100 102 205 209 263

# %%
sort(dataR$state)
# Out:
#    [1] "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK"
#   [15] "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK"
#   [29] "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK"
#   [43] "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK"
#   [57] "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK"
#   [71] "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK"
#   [85] "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK"
#   [99] "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK"
#  [113] "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK"
#  [127] "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK"
#  [141] "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK"
#  [155] "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK" "AK"
# ...

# %% [markdown]
# `$` in R is like `[]` in other languages, it is used to access the columns
#
# `table()` shows the frequency of the states and list them like a table
#
# we can use `head()` and `tail()` for each column as well
#
# sort use to sort ascending

# %% [markdown]
# ## Question 4

# %%
product_data <- read.csv("/anvil/projects/tdm/data/icecream/combined/products.csv")
head(product_data)
# Out:
#   brand key  name
# 1 bj    0_bj Salted Caramel Core
# 2 bj    1_bj Netflix & Chilll'd\342\204\242
# 3 bj    2_bj Chip Happens
# 4 bj    3_bj Cannoli
# 5 bj    4_bj Gimme S\342\200\231more!\342\204\242
# 6 bj    5_bj Peanut Butter Half Baked\302\256
#   subhead
# 1 Sweet Cream Ice Cream with Blonde Brownies & a Salted Caramel Core
# 2 Peanut Butter Ice Cream with Sweet & Salty Pretzel Swirls & Fudge Brownies
# 3 A Cold Mess of Chocolate Ice Cream with Fudge Chips & Crunchy Potato Chip Swirls
# 4 Mascarpone Ice Cream with Fudge-Covered Pastry Shell Pieces & Mascarpone Swirls
# 5 Toasted Marshmallow Ice Cream with Chocolate Cookie Swirls, Graham Cracker Swirls & Fudge Flakes
# 6 Chocolate & Peanut Butter Ice Creams Mixed with Gobs of Peanut Butter Cookie Dough & Fudge Brownies
#   description
# ...

# %%
table(product_data$brand)
# Out:
#      bj breyers      hd talenti
#      57      69      70      45

# %%
review_data <- read.csv("/anvil/projects/tdm/data/icecream/combined/reviews.csv")
head(review_data)
# Out:
#   brand key  author         date       stars
# 1 bj    0_bj Ilovebennjerry 2017-04-15 3
# 2 bj    0_bj Sweettooth909  2020-01-05 5
# 3 bj    0_bj LaTanga71      2018-04-26 3
# 4 bj    0_bj chicago220     2018-01-14 5
# 5 bj    0_bj Kassidyk       2020-07-24 1
# 6 bj    0_bj Nikiera        2020-07-23 2
#   title                                   helpful_yes helpful_no
# 1 Not enough brownies!                    10          3
# 2 I\342\200\231m OBSESSED with this pint!  3          0
# 3 My favorite...More Caramel Please        5          2
# 4 Obsessed!!!                             24          1
# 5 Worst Ice Cream Ever!                    1          5
# 6 Way Too Salty                            3          1
#   text
# ...

# %%
table(review_data$brand)
# Out:
#      bj breyers      hd talenti
#    7943    5007    4655    4069

# %% [markdown]
# we repeat the process,
#
# 1.  Read the data using `read.csv()`
# 2.  Used `head()` to know more about the data, the name of columns,...
# 3.  Use `table()` to list the appearance times

# %% [markdown]
# ## Question 5

# %%
plot(table(product_data$brand))
# Out:
# plot without title

# %%
plot(table(review_data$brand))
# Out:
# plot without title

# %% [markdown]
# The `plot()` is used to visualize the data

# %% [markdown]
# ## Pledge
#
# By submitting this work I hereby pledge that this is my own, personal work. I've acknowledged in the designated place at the top of this file all sources that I used to complete said work, including but not limited to: online resources, books, and electronic communications. I've noted all collaboration with fellow students and/or TA's. I did not copy or plagiarize another's work.
#
# > As a Boilermaker pursuing academic excellence, I pledge to be honest and true in all that I do. Accountable together – We are Purdue.
